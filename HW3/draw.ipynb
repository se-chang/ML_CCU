# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
history = np.load("history/train_history.npy")

# %%
print(history)
# Out:
# [[4.81362601 0.0083154 ]
#  [4.78170324 0.00968499]
#  [4.77738282 0.01193504]
#  [4.66464036 0.02073958]
#  [4.50854964 0.03746821]
#  [4.42375713 0.04695754]
#  [4.32199006 0.06290354]
#  [4.15601299 0.0898063 ]
#  [3.90789422 0.12649188]
#  [3.52384202 0.19810214]
#  [3.05075224 0.2829192 ]
#  [2.56264885 0.38133438]
#  [2.08191732 0.48376052]
#  [1.70462314 0.57366465]
#  [1.41389659 0.63637253]
#  [1.16030055 0.69859128]
#  [0.93587096 0.7503424 ]
#  [0.73940701 0.8044414 ]
#  [0.60596975 0.83486597]
#  [0.50605225 0.86196438]
#  [0.46188649 0.87575816]
#  [0.38957167 0.89199765]
#  [0.34827183 0.90735667]
#  [0.28675959 0.92242222]
#  [0.27322107 0.92868322]
#  [0.24037014 0.93729211]
#  [0.21171894 0.94120524]
#  [0.1822375  0.94864018]
#  [0.17599369 0.95265114]
#  [0.16054393 0.95186851]
#  [0.16162625 0.9552925 ]
#  [0.13686742 0.96165133]
#  [0.13715122 0.96135785]
#  [0.11241013 0.96576012]
#  [0.12095453 0.96644492]
#  [0.10635133 0.97162981]
#  [0.10170539 0.97241244]
#  [0.10079742 0.96918411]
#  [0.0958382  0.97251027]
#  [0.09356065 0.97476032]]

# %%
plt.plot(history[:,0], 'g', label='loss')
plt.legend(loc='upper right')
plt.title('model loss')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history[:,1], 'b', label='acc')
plt.legend(loc='upper left')
plt.title('model acc')
plt.xlabel('epoch')
plt.show()
